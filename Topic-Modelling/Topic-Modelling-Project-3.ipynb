# %% [markdown]
# ### Topic Modelling on News Article

# %%
#importing reuired libraries
import gensim

from nltk.stem import WordNetLemmatizer, SnowballStemmer
#creating instance for snowballstemmer
stemmer = SnowballStemmer("english")

# %%
#creating functions for processing part
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token)>3:
            result.append(lemmatize_stemming(token).lower())
            
    return result

# %%
#extracting the saved text file from the directory
import glob
docs_text=[]  #store text of all documents
for files in glob.glob('*'): #all files in the present directory
    if(files.startswith('news1')):
        handle = open(files,'r',encoding="utf-8")
        docs_text.append(handle.read())  
        handle.close()

# %%
#displaying the content of file
docs_text
# Out:
# ['  NEW DELHI: The industry on Monday said the steep 23.9 per cent contraction in the GDP in April-June was on expected lines reflecting the "stalling of economic activities" due to the lockdown imposed in response to coronavirus pandemic. The industry, however, said it anticipates the economy to stage a gradual recovery in the coming quarters on account of reforms, the Rs 20 lakh crore stimulus package and measures taken by the Reserve Bank. India\'s GDP shrank steeply by 23.9 per cent in the April-June period as the coronavirus lockdowns battered an already slowing economy. Agriculture was the only outlier as all other sectors, including manufacturing, construction and services, suffered steep declines. CII Director General Chandrajit Banerjee said the large contraction in the first quarter GDP print at 23.9 per cent was widely expected, and it reflects the wide-spread stalling of economic activities due to the stringent lockdown in response to the pandemic. "Even as the first half of the current fiscal is expected to remain weak, we can expect a recovery in the second half led by supportive fiscal and monetary policies," Banerjee said. In this context, he said, the localised lockdowns being imposed by state and district administrations may be avoided so that the economic recovery can be kept on track. "Going forward, we are anticipating contractions -though a bit better in numbers- in the July- September quarter and the October- December quarter as well. However, in the quarters post that, we anticipate some amount of recovery to take place," Assocham president Niranjan Hiranandani said. The country would witness even a recovered growth curve in the quarters after that due to a series of measures, he stated. â\x80\x9cThe Rs 20 lakh crore stimulus package, the measures taken by the Reserve Bank of India and the administrative reforms would show a positive outcome in the economy,â\x80\x9d he said. PHDCCI President D K Aggarwal said the reforms undertaken by the government will bring the economy back on its growth path sooner than later. India\'s economy had grown by 5.2 per cent in the same quarter of last fiscal, as per the data released by the National Statistical Office.  NEW DELHI: Vidyamandir Classes on Tuesday said it has started online classes under a Rapid Success Programme for Class 12 pass students preparing for IIT Joint Entrance Examination (JEE) and National Eligibility cum Entrance Test (NEET).\n\n\nThis would be the most rigorous, success-oriented programme for students preparing for JEE/NEET 2021 in the country, VMC said, adding that students of this course will be entitled to a flat 50 per cent COVID Support scholarship.\n\nDue to the prevailing uncertainty triggered by Covid-19 crises, this course has a flexible format which allows an exit of the students who would crack NEET/IIT-JEE exams in September-2020 with a refund of the balance course fee and the rest can continue the preparation for entrance exams of 2021, the institute said.\n\nVMC said it has conceptualised this nine-month course to emphasise on a focused approach of propelling students to score higher grades within the reduced time frame.\n\nDuring the entire period of this course, 20+ hours of course delivery is targeted every week from teachers in India (including VMC Founders) who have a good track record of excellent results in the past three decades.\n\n"This special course is designed for those students who are aiming to score higher marks in their NEET and IITJEE exam. During this unpredictable situation, it is hard to define what is waiting for them in the future," Brij Mohan Gupta, Founder, Vidyamandir Classes, said in a statement.\n\n"So, this course will work as a backup plan for 12th pass students who can continue preparation for the 2021 entrance examination and also can exit from the course if they get selected in NEET/IITJEE 2020. We are confident of a very successful outcome for students through the Rapid Success Courses," he said ...

# %%
#processing the data for tokenization and lemmatization

processed_docs = []
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text,pos='v'))

for doc in docs_text:
    processed_docs.append(preprocess(doc))
processed_docs
# Out:
# [['delhi',
#   'industri',
#   'monday',
#   'say',
#   'steep',
#   'cent',
#   'contract',
#   'april',
#   'june',
#   'expect',
#   'line',
#   'reflect',
#   'stall',
#   'econom',
#   'activ',
#   'lockdown',
#   'impos',
#   'respons',
#   'coronavirus',
#   'pandem',
#   'industri',
#   'say',
#   'anticip',
#   'economi',
#   'stage',
#   'gradual',
#   'recoveri',
#   'come',
#   'quarter',
#   'account',
#   'reform',
#   'lakh',
#   'crore',
#   'stimulus',
#   'packag',
#   'measur',
#   'take',
#   'reserv',
#   'bank',
#   'india',
#   'shrink',
#   'steepli',
#   'cent',
#   'april',
#   'june',
#   'period',
#   'coronavirus',
#   'lockdown',
#   'batter',
#   'slow',
#   'economi',
#   'agricultur',
#   'outlier',
#   'sector',
#   'includ',
#   'manufactur',
#   'construct',
#   'servic',
#   'suffer',
#   'steep',
#   'declin',
#   'director',
#   'general',
#   'chandrajit',
#   'banerje',
#   'say',
#   'larg',
#   'contract',
#   'quarter',
#   'print',
#   'cent',
#   'wide',
#   'expect',
#   'reflect',
#   'wide',
#   'spread',
#   'stall',
#   'econom',
#   'activ',
#   'stringent',
#   'lockdown',
#   'respons',
#   'pandem',
#   'half',
#   'current',
#   'fiscal',
#   'expect',
#   'remain',
#   'weak',
#   'expect',
#   'recoveri',
#   'second',
#   'half',
#   'support',
#   'fiscal',
#   'monetari',
#   'polici',
#   'banerje',
#   'say',
#   'context',
#   'say',
#   'localis',
#   'lockdown',
#   'impos',
#   'state',
#   'district',
#   'administr',
#   'avoid',
#   'econom',
#   'recoveri',
#   'keep',
#   'track',
#   'go',
#   'forward',
#   'anticip',
#   'contract',
#   'better',
#   'number',
#   'juli',
#   'septemb',
#   'quarter',
#   'octob',
#   'decemb',
#   'quarter',
#   'quarter',
#   'post',
#   'anticip',
#   'recoveri',
#   'place',
#   'assocham',
#   'presid',
#   'niranjan',
#   'hiranandani',
#   'say',
#   'countri',
#   'wit',
#   'recov',
#   'growth',
#   'curv',
#   'quarter',
#   'seri',
#   'measur',
#   'state',
#   'lakh',
#   'crore',
#   'stimulus',
#   'packag',
#   'measur',
#   'take',
#   'reserv',
#   'bank',
#   'india',
#   'administr',
#   'reform',
#   'posit',
#   'outcom',
#   'economi',
#   'say',
#   'phdcci',
#   'presid',
#   'aggarw',
#   'say',
#   'reform',
#   'undertak',
#   'govern',
#   'bring',
#   'economi',
#   'growth',
#   'path',
#   'sooner',
#   'later',
#   'india',
#   'economi',
#   'grow',
#   'cent',
#   'quarter',
#   'fiscal',
#   'data',
#   'releas',
#   'nation',
#   'statist',
#   'offic',
#   'delhi',
#   'vidyamandir',
#   'class',
#   'tuesday',
#   'say',
#   'start',
#   'onlin',
#   'class',
#   'rapid',
#   'success',
#   'programm',
#   'class',
#   'pass',
#   'student',
#   'prepar',
#   'joint',
#   'entranc',
#   'examin',
#   'nation',
#   'elig',
#   'entranc',
#   'test',
#   'neet',
#   'rigor',
#   'success',
#   'orient',
#   'programm',
#   'student',
#   'prepar',
#   'neet',
#   'countri',
#   'say',
#   'add',
#   'student',
#   'cours',
#   'entitl',
#   'flat',
#   'cent',
#   'covid',
#   'support',
#   'scholarship',
#   'prevail',
#   'uncertainti',
#   'trigger',
#   'covid',
#   'crise',
#   'cours',
#   'flexibl',
#   'format',
#   'allow',
#   'exit',
#   'student',
#   'crack',
#   'neet',
#   'exam',
#   'septemb',
#   'refund',
#   'balanc',
#   'cours',
#   'rest',
#   'continu',
#   'prepar',
#   'entranc',
#   'exam',
#   'institut',
#   'say',
#   'say',
#   'conceptualis',
#   'month',
#   'cours',
#   'emphasis',
#   'focus',
#   'approach',
#   'propel',
#   'student',
#   'score',
#   'higher',
#   'grade',
#   'reduc',
#   'time',
#   'frame',
#   'entir',
#   'period',
#   'cours',
#   'hour',
#   'cours',
#   'deliveri',
#   'target',
#   'week',
#   'teacher',
#   'india',
#   'includ',
#   'founder',
#   'good',
#   'track',
#   'record',
#   'excel',
#   'result',
#   'past',
#   'decad',
#   'special',
#   'cours',
#   'design',
#   'student',
#   'aim',
#   'score',
#   'higher',
#   'mark',
#   'neet',
#   'iitje',
#   'exam',
#   'unpredict',
#   'situat',
#   'hard',
#   'defin',
#   'wait',
#   'futur',
#   'brij',
#   'mohan',
#   'gupta',
#   'founder',
#   'vidyamandir',
#   'class',
#   'say',
#   'statement',
#   'cours',
#   'work',
#   'backup',
#   'plan',
#   'pass',
#   'student',
#   'continu',
#   'prepar',
#   'entranc',
#   'examin',
#   'exit',
#   'cours',
#   'select',
#   'neet',
#   'iitje',
#   'confid',
#   'success',
#   'outcom',
#   'student',
#   'rapid',
#   'success',
#   'cours',
#   'say',
#   'student',
#   'receiv',
#   'special',
#   'design',
#   'studi',
#   'materi',
#   'high',
#   'focus',
#   'import',
#   'concept',
#   'practic',
#   'question',
#   'cours',
#   'design',
#   'help',
#   'dropper',
#   'prepar',
#   'strateg',
#   'short',
#   'period',
#   'time',
#   'believ',
#   'student',
#   'definit',
#   'score',
#   'higher',
#   'mark',
#   'follow',
#   'studi',
#   'materi',
#   'practic',
#   'session',
#   'meticul',
#   'gupta',
#   'say',
#   'student',
#   'inspir',
#   'appear',
#   'mock',
#   'test',
#   'attend',
#   'practic',
#   'session',
#   'order',
#   'boost',
#   'confid',
#   'student',
#   'wish',
#   'combin',
#   'crash',
#   'cours',
#   'rapid',
#   'success',
#   'cours',
#   'addit',
#   'save',
#   'packag',
#   'student',
#   'fast',
#   'track',
#   'success',
#   'programm',
#   'crash',
#   'cours',
#   'neet',
#   'admiss',
#   'rapid',
#   'success',
#   'program',
#   'septemb',
#   'batch',
#   'later',
#   'year',
#   'say',
#   'add',
#   'student',
#   'current',
#   'rapid',
#   'cours',
#   'upgrad',
#   'regular',
#   'classroom',
#   'programm',
#   'anytim',
#   'delhi',
#   'surg',
#   'hire',
#   'remot',
#   'job',
#   'india',
#   'month',
#   'work',
#   'home',
#   'job',
#   'wit',
#   'fold',
#   'jump',
#   'compar',
#   'covid',
#   'level',
#   'report',
#   'say',
#   'tuesday',
#   'remot',
#   'work',
#   'see',
#   'employe',
#   'enjoy',
#   'greater',
#   'flexibl',
#   'control',
#   'person',
#   'profession',
#   'live',
#   'includ',
#   'save',
#   'commut',
#   'time',
#   'result',
#   'work',
#   'home',
#   'job',
#   'wit',
#   'seven',
#   'fold',
#   'growth',
#   'applic',
#   'month',
#   'compar',
#   'covid',
#   'time',
#   'hire',
#   'remot',
#   'job',
#   'see',
#   'robust',
#   'growth',
#   'increas',
#   'time',
#   'compar',
#   'covid',
#   'level',
#   'year',
#   'accord',
#   'report',
#   'lead',
#   'portal',
#   'naukri',
#   'percentag',
#   'contribut',
#   'job',
#   'go',
#   'fold',
#   'versus',
#   'result',
#   'global',
#   'pandem',
#   'keyword',
#   'work',
#   'home',
#   'search',
#   'keyword',
#   'jobseek',
#   'month',
#   'naukri',
#   'platform',
#   'interest',
#   'note',
#   'tradit',
#   'offic',
#   'base',
#   'grind',
#   'role',
#   'sale',
#   'busi',
#   'develop',
#   'custom',
#   'care',
#   'agent',
#   'offer',
#   'option',
#   'say',
#   'pawan',
#   'goyal',
#   'chief',
#   'busi',
#   'offic',
#   'naukri',
#   'half',
#   'remot',
#   'post',
#   'ite',
#   'sector',
#   'result',
#   'robust',
#   'growth',
#   'job',
#   'industri',
#   'softwar',
#   'educ',
#   'teach',
#   'internet',
#   'commerc',
#   'contribut',
#   'quarter',
#   'work',
#   'home',
#   'job',
#   'job',
#   'emerg',
#   'unlik',
#   'sector',
#   'publish',
#   'bfsi',
#   'educ',
#   'teach',
#   'convent',
#   'requir',
#   'physic',
#   'presenc',
#   'employe',
#   'impact',
#   'industri',
#   'like',
#   'travel',
#   'staff',
#   'continu',
#   'declin',
#   'hire',
#   'remot',
#   'job',
#   'report',
#   'say',
#   'trend',
#   'recur',
#   'topic',
#   'discuss',
#   'webinar',
#   'queri',
#   'direct',
#   'industri',
#   'expert',
#   'jobseek',
#   'remot',
#   'work',
#   'job',
#   'report',
#   'add']]

# %%
#bag of words on the data set
dictionary = gensim.corpora.Dictionary(processed_docs)

# %%
print (dictionary)
# Out:
# Dictionary(314 unique tokens: ['accord', 'account', 'activ', 'add', 'addit']...)

# %%
#Create the Bag-of-words model for each document i.e for each document we create a dictionary reporting how many
#words and how many times those words appear. Save this to 'bow_corpus'
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# %%
#displaying the corpus saved
bow_corpus
# Out:
# [[(0, 1),
#   (1, 1),
#   (2, 2),
#   (3, 3),
#   (4, 1),
#   (5, 2),
#   (6, 1),
#   (7, 1),
#   (8, 1),
#   (9, 1),
#   (10, 1),
#   (11, 1),
#   (12, 3),
#   (13, 1),
#   (14, 1),
#   (15, 1),
#   (16, 1),
#   (17, 2),
#   (18, 1),
#   (19, 1),
#   (20, 1),
#   (21, 1),
#   (22, 1),
#   (23, 2),
#   (24, 2),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 2),
#   (35, 1),
#   (36, 5),
#   (37, 1),
#   (38, 1),
#   (39, 4),
#   (40, 1),
#   (41, 1),
#   (42, 1),
#   (43, 1),
#   (44, 1),
#   (45, 3),
#   (46, 1),
#   (47, 1),
#   (48, 2),
#   (49, 1),
#   (50, 1),
#   (51, 3),
#   (52, 3),
#   (53, 2),
#   (54, 1),
#   (55, 1),
#   (56, 2),
#   (57, 2),
#   (58, 15),
#   (59, 5),
#   (60, 1),
#   (61, 2),
#   (62, 1),
#   (63, 2),
#   (64, 2),
#   (65, 1),
#   (66, 1),
#   (67, 1),
#   (68, 1),
#   (69, 1),
#   (70, 2),
#   (71, 1),
#   (72, 1),
#   (73, 3),
#   (74, 1),
#   (75, 3),
#   (76, 1),
#   (77, 1),
#   (78, 1),
#   (79, 1),
#   (80, 1),
#   (81, 1),
#   (82, 3),
#   (83, 5),
#   (84, 2),
#   (85, 1),
#   (86, 1),
#   (87, 1),
#   (88, 2),
#   (89, 1),
#   (90, 1),
#   (91, 1),
#   (92, 4),
#   (93, 3),
#   (94, 2),
#   (95, 1),
#   (96, 2),
#   (97, 4),
#   (98, 1),
#   (99, 1),
#   (100, 3),
#   (101, 1),
#   (102, 2),
#   (103, 2),
#   (104, 3),
#   (105, 1),
#   (106, 1),
#   (107, 1),
#   (108, 2),
#   (109, 1),
#   (110, 1),
#   (111, 1),
#   (112, 1),
#   (113, 2),
#   (114, 1),
#   (115, 1),
#   (116, 1),
#   (117, 1),
#   (118, 1),
#   (119, 1),
#   (120, 1),
#   (121, 1),
#   (122, 5),
#   (123, 2),
#   (124, 3),
#   (125, 1),
#   (126, 1),
#   (127, 1),
#   (128, 3),
#   (129, 1),
#   (130, 3),
#   (131, 4),
#   (132, 1),
#   (133, 2),
#   (134, 1),
#   (135, 1),
#   (136, 2),
#   (137, 3),
#   (138, 1),
#   (139, 5),
#   (140, 5),
#   (141, 1),
#   (142, 1),
#   (143, 1),
#   (144, 1),
#   (145, 1),
#   (146, 10),
#   (147, 2),
#   (148, 1),
#   (149, 1),
#   (150, 1),
#   (151, 2),
#   (152, 1),
#   (153, 2),
#   (154, 2),
#   (155, 1),
#   (156, 2),
#   (157, 1),
#   (158, 2),
#   (159, 1),
#   (160, 1),
#   (161, 1),
#   (162, 1),
#   (163, 4),
#   (164, 1),
#   (165, 2),
#   (166, 2),
#   (167, 3),
#   (168, 1),
#   (169, 1),
#   (170, 1),
#   (171, 1),
#   (172, 1),
#   (173, 4),
#   (174, 2),
#   (175, 3),
#   (176, 6),
#   (177, 1),
#   (178, 1),
#   (179, 1),
#   (180, 1),
#   (181, 1),
#   (182, 3),
#   (183, 1),
#   (184, 1),
#   (185, 1),
#   (186, 1),
#   (187, 2),
#   (188, 1),
#   (189, 3),
#   (190, 3),
#   (191, 2),
#   (192, 1),
#   (193, 1),
#   (194, 1),
#   (195, 1),
#   (196, 3),
#   (197, 1),
#   (198, 1),
#   (199, 1),
#   (200, 1),
#   (201, 1),
#   (202, 1),
#   (203, 1),
#   (204, 1),
#   (205, 1),
#   (206, 2),
#   (207, 3),
#   (208, 5),
#   (209, 1),
#   (210, 2),
#   (211, 1),
#   (212, 1),
#   (213, 1),
#   (214, 1),
#   (215, 4),
#   (216, 1),
#   (217, 1),
#   (218, 8),
#   (219, 1),
#   (220, 1),
#   (221, 5),
#   (222, 1),
#   (223, 1),
#   (224, 1),
#   (225, 4),
#   (226, 1),
#   (227, 1),
#   (228, 2),
#   (229, 3),
#   (230, 1),
#   (231, 1),
#   (232, 1),
#   (233, 1),
#   (234, 6),
#   (235, 4),
#   (236, 1),
#   (237, 2),
#   (238, 2),
#   (239, 1),
#   (240, 4),
#   (241, 1),
#   (242, 2),
#   (243, 1),
#   (244, 1),
#   (245, 2),
#   (246, 19),
#   (247, 1),
#   (248, 3),
#   (249, 1),
#   (250, 1),
#   (251, 3),
#   (252, 2),
#   (253, 1),
#   (254, 3),
#   (255, 1),
#   (256, 1),
#   (257, 2),
#   (258, 1),
#   (259, 1),
#   (260, 1),
#   (261, 1),
#   (262, 1),
#   (263, 1),
#   (264, 1),
#   (265, 2),
#   (266, 1),
#   (267, 1),
#   (268, 1),
#   (269, 2),
#   (270, 1),
#   (271, 2),
#   (272, 1),
#   (273, 1),
#   (274, 2),
#   (275, 1),
#   (276, 2),
#   (277, 1),
#   (278, 1),
#   (279, 14),
#   (280, 2),
#   (281, 7),
#   (282, 1),
#   (283, 2),
#   (284, 1),
#   (285, 2),
#   (286, 1),
#   (287, 2),
#   (288, 1),
#   (289, 2),
#   (290, 5),
#   (291, 1),
#   (292, 3),
#   (293, 1),
#   (294, 1),
#   (295, 1),
#   (296, 1),
#   (297, 2),
#   (298, 1),
#   (299, 1),
#   (300, 1),
#   (301, 1),
#   (302, 1),
#   (303, 1),
#   (304, 2),
#   (305, 1),
#   (306, 1),
#   (307, 1),
#   (308, 1),
#   (309, 2),
#   (310, 1),
#   (311, 3),
#   (312, 7),
#   (313, 2)]]

# %%
#creating the model for topic modelling
lda_model =  gensim.models.ldamodel.LdaModel(bow_corpus, num_topics =20,id2word = dictionary,passes = 4,random_state=100,
                                           update_every=1,)

# %%
for idx, topic in lda_model.print_topics():
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.008*"say" + 0.007*"cours" + 0.007*"student" + 0.006*"job" + 0.005*"success" + 0.005*"work" + 0.005*"industri" + 0.005*"remot" + 0.004*"neet" + 0.004*"quarter"
#
#
# Topic: 1
# Words: 0.003*"practic" + 0.003*"posit" + 0.003*"profession" + 0.003*"print" + 0.003*"prevail" + 0.003*"presid" + 0.003*"presenc" + 0.003*"prepar" + 0.003*"programm" + 0.003*"post"
#
#
# Topic: 2
# Words: 0.011*"say" + 0.008*"cours" + 0.007*"student" + 0.006*"job" + 0.006*"quarter" + 0.005*"success" + 0.005*"remot" + 0.005*"industri" + 0.005*"neet" + 0.005*"work"
#
#
# Topic: 3
# Words: 0.011*"say" + 0.009*"cours" + 0.008*"student" + 0.007*"job" + 0.006*"quarter" + 0.006*"work" + 0.005*"growth" + 0.005*"success" + 0.005*"time" + 0.005*"remot"
#
#
# Topic: 4
# Words: 0.009*"say" + 0.007*"student" + 0.006*"cours" + 0.005*"quarter" + 0.005*"success" + 0.005*"neet" + 0.005*"remot" + 0.005*"rapid" + 0.004*"industri" + 0.004*"job"
#
#
# Topic: 5
# Words: 0.008*"cours" + 0.007*"say" + 0.007*"student" + 0.005*"job" + 0.005*"quarter" + 0.005*"neet" + 0.005*"success" + 0.005*"cent" + 0.005*"work" + 0.004*"rapid"
#
#
# Topic: 6
# Words: 0.014*"say" + 0.009*"job" + 0.009*"cours" + 0.008*"student" + 0.007*"work" + 0.006*"quarter" + 0.005*"economi" + 0.005*"remot" + 0.005*"covid" + 0.005*"india"
#
#
# Topic: 7
# Words: 0.009*"cours" + 0.009*"student" + 0.008*"say" + 0.006*"remot" + 0.006*"quarter" + 0.006*"job" + 0.005*"work" + 0.005*"success" + 0.005*"covid" + 0.005*"prepar"
#
#
# Topic: 8
# Words: 0.005*"cours" + 0.005*"say" + 0.005*"student" + 0.004*"job" + 0.004*"quarter" + 0.004*"success" + 0.004*"remot" + 0.004*"work" + 0.004*"industri" + 0.004*"programm"
#
#
# Topic: 9
# Words: 0.004*"say" + 0.004*"cours" + 0.003*"student" + 0.003*"job" + 0.003*"remot" + 0.003*"quarter" + 0.003*"work" + 0.003*"neet" + 0.003*"prepar" + 0.003*"success"
#
#
# Topic: 10
# Words: 0.006*"say" + 0.006*"cours" + 0.005*"student" + 0.005*"job" + 0.004*"quarter" + 0.004*"success" + 0.004*"work" + 0.004*"covid" + 0.004*"rapid" + 0.004*"month"
#
#
# Topic: 11
# Words: 0.010*"say" + 0.009*"cours" + 0.008*"student" + 0.006*"job" + 0.005*"quarter" + 0.005*"neet" + 0.005*"work" + 0.005*"remot" + 0.005*"india" + 0.005*"economi"
#
#
# Topic: 12
# Words: 0.004*"say" + 0.004*"student" + 0.004*"cours" + 0.004*"job" + 0.003*"remot" + 0.003*"prepar" + 0.003*"neet" + 0.003*"work" + 0.003*"cent" + 0.003*"growth"
#
#
# Topic: 13
# Words: 0.007*"say" + 0.007*"cours" + 0.006*"student" + 0.006*"job" + 0.005*"remot" + 0.004*"work" + 0.004*"neet" + 0.004*"quarter" + 0.004*"growth" + 0.004*"success"
#
#
# Topic: 14
# Words: 0.032*"say" + 0.025*"cours" + 0.024*"student" + 0.017*"job" + 0.014*"quarter" + 0.012*"success" + 0.012*"work" + 0.010*"neet" + 0.010*"remot" + 0.009*"economi"
#
#
# Topic: 15
# Words: 0.007*"cours" + 0.007*"say" + 0.006*"student" + 0.006*"quarter" + 0.005*"job" + 0.005*"success" + 0.005*"neet" + 0.005*"work" + 0.004*"cent" + 0.004*"time"
#
#
# Topic: 16
# Words: 0.009*"say" + 0.008*"student" + 0.007*"cours" + 0.007*"job" + 0.005*"success" + 0.005*"remot" + 0.005*"quarter" + 0.005*"work" + 0.005*"prepar" + 0.005*"time"
#
#
# Topic: 17
# Words: 0.008*"say" + 0.006*"student" + 0.006*"cours" + 0.005*"success" + 0.005*"job" + 0.004*"quarter" + 0.004*"neet" + 0.004*"work" + 0.004*"remot" + 0.004*"growth"
#
#
# Topic: 18
# Words: 0.006*"say" + 0.006*"cours" + 0.006*"student" + 0.005*"quarter" + 0.005*"job" + 0.004*"success" + 0.004*"work" + 0.004*"neet" + 0.004*"rapid" + 0.004*"cent"
#
#
# Topic: 19
# Words: 0.005*"say" + 0.005*"student" + 0.005*"job" + 0.005*"cours" + 0.004*"work" + 0.004*"rapid" + 0.004*"success" + 0.004*"quarter" + 0.004*"expect" + 0.004*"remot"

# %%
#extracting test set frpm the file folder
test_set=[]  #store text of all documents
for files in glob.glob('*'): #all files in the present directory
    if(files.startswith('news2')):
        handle = open(files,'r')
        test_set.append(handle.read())  
        handle.close()

# %%
test_set
# Out:
# [' On Monday, the government released economic data for the first quarter of the current fiscal year revealing a historic contraction of 23.9 per cent over the three months of April, May and June.\xa0 The COVID-19 outbreak, the subsequent lockdowns enforced by the central government and state governments, and the paralysis in business activity that they triggered, have led to the largest quarterly slump in India\'s GDP figures since such figures were first published (1996). India\'s GDP during the fourth quarter of the last fiscal stood at 3.1 per cent, with overall growth during the fiscal pegged at 5.2 per cent.\xa0 A contraction in India\'s GDP was largely expected by economists, however the majority had predicted a shrinkage no greater than 20 per cent. Moreover, the latest figures have also sparked suggestions that further downward revisions could be on the cards particularly because, given the lack of business activity that took place during the first quarter, there are concerns that data collection may not have been as robust as it is typically is.\xa0 A contraction of 23.9 per cent simply means that the total value of all goods and services fell by that proportion as compared the same three-month period last year. The government\'s data also shows that, with the exception of agriculture which grew at a rate of 3.4 per cent, every other sector of the economy contracted.\xa0 The distress was most acute in the mining (-23 per cent), construction (-50 per cent), trade, hospitality and other services (47 per cent) and manufacturing (-39 per cent) sectors – incidentally all sectors key to driving employment.\xa0 In terms of what has fuelled the downward trajectory of India\'s GDP, one needs to take a slightly deeper look at the economy\'s four primary engines of growth – consumption, government expenditure, investment and the nation\'s current account deficit (imports – exports).\xa0 Consumption, which typically has the greatest impact on GDP, in the last quarter accounted for 56.4 per cent of the country\'s GDP. Investment, also known as the the demand by private sector enterprises, made up 32 per cent of India\'s GDP. Government expenditure\'s share of the GDP stood at 11 per cent.\xa0 India\'s current account deficit has, historically, been in the negative, but recorded positive rates in the quarter that just past, implying that exports exceeded imports. While this may add positively to the GDP, it is, ultimately, a clear signal of muted demand with imports dropping to dire levels.\xa0 A drop of Rs 5,31,803 crore in private consumption or 27 per cent (compared to the same period last year) has been the key driver behind India\'s economic contraction. Private sector investment falling by Rs 5,33,003 crore follows closely behind, with the two components collectively accounting for 88 per cent of the total GDP shrinkage.\xa0 Government expenditure, in fact, rose by 16 per cent over the last quarter, specifically due to the relief measures instituted by the central government, but nevertheless could compensate for just 6 per cent of the total fall in demand instigated by the drop in consumption and investment.\xa0\n\n\nRELATED NEWS \n\n\n\n\n\nRetail, MSME\xa0borrowers\xa0may get 6-month moratorium on loan principal repayment\n\n\n\n\n\n\nCovid impact: India\'s Q1 GDP shrinks 23.9%, is the worst over?\n\n\n\n\n\n\nRocking rally just a mirage or the beginning of a multi-year bull run? D-street experts remain divided\n\n\n\n\n\n In the absence of increased government expenditure, which doesn\'t appear to be on the horizon, several analysts have noted that further contractions could be on the cards in the upcoming quarters. If India records a contraction in the current quarter, it would have officially entered into a recession (defined as two consecutive quarters of contraction).\xa0 As for when India may begin to experience signs of an economic recovery, this will hinge entirely upon the way in which the COVID-19 outbreak evolv ...

# %%
#processing for the test_set
processed_test=[]
for doc in test_set:
    processed_test.append(preprocess(doc))
processed_test
# Out:
# [['monday',
#   'govern',
#   'releas',
#   'econom',
#   'data',
#   'quarter',
#   'current',
#   'fiscal',
#   'year',
#   'reveal',
#   'histor',
#   'contract',
#   'cent',
#   'month',
#   'april',
#   'june',
#   'covid',
#   'outbreak',
#   'subsequ',
#   'lockdown',
#   'enforc',
#   'central',
#   'govern',
#   'state',
#   'govern',
#   'paralysi',
#   'busi',
#   'activ',
#   'trigger',
#   'largest',
#   'quarter',
#   'slump',
#   'india',
#   'figur',
#   'figur',
#   'publish',
#   'india',
#   'fourth',
#   'quarter',
#   'fiscal',
#   'stand',
#   'cent',
#   'overal',
#   'growth',
#   'fiscal',
#   'peg',
#   'cent',
#   'contract',
#   'india',
#   'larg',
#   'expect',
#   'economist',
#   'major',
#   'predict',
#   'shrinkag',
#   'greater',
#   'cent',
#   'latest',
#   'figur',
#   'spark',
#   'suggest',
#   'downward',
#   'revis',
#   'card',
#   'particular',
#   'give',
#   'lack',
#   'busi',
#   'activ',
#   'take',
#   'place',
#   'quarter',
#   'concern',
#   'data',
#   'collect',
#   'robust',
#   'typic',
#   'contract',
#   'cent',
#   'simpli',
#   'mean',
#   'total',
#   'valu',
#   'good',
#   'servic',
#   'fell',
#   'proport',
#   'compar',
#   'month',
#   'period',
#   'year',
#   'govern',
#   'data',
#   'show',
#   'except',
#   'agricultur',
#   'grow',
#   'rate',
#   'cent',
#   'sector',
#   'economi',
#   'contract',
#   'distress',
#   'acut',
#   'mine',
#   'cent',
#   'construct',
#   'cent',
#   'trade',
#   'hospit',
#   'servic',
#   'cent',
#   'manufactur',
#   'cent',
#   'sector',
#   'incident',
#   'sector',
#   'drive',
#   'employ',
#   'term',
#   'fuel',
#   'downward',
#   'trajectori',
#   'india',
#   'need',
#   'slight',
#   'deeper',
#   'look',
#   'economi',
#   'primari',
#   'engin',
#   'growth',
#   'consumpt',
#   'govern',
#   'expenditur',
#   'invest',
#   'nation',
#   'current',
#   'account',
#   'deficit',
#   'import',
#   'export',
#   'consumpt',
#   'typic',
#   'greatest',
#   'impact',
#   'quarter',
#   'account',
#   'cent',
#   'countri',
#   'invest',
#   'know',
#   'demand',
#   'privat',
#   'sector',
#   'enterpris',
#   'cent',
#   'india',
#   'govern',
#   'expenditur',
#   'share',
#   'stand',
#   'cent',
#   'india',
#   'current',
#   'account',
#   'deficit',
#   'histor',
#   'negat',
#   'record',
#   'posit',
#   'rat',
#   'quarter',
#   'past',
#   'impli',
#   'export',
#   'exceed',
#   'import',
#   'posit',
#   'ultim',
#   'clear',
#   'signal',
#   'mute',
#   'demand',
#   'import',
#   'drop',
#   'dire',
#   'level',
#   'drop',
#   'crore',
#   'privat',
#   'consumpt',
#   'cent',
#   'compar',
#   'period',
#   'year',
#   'driver',
#   'india',
#   'econom',
#   'contract',
#   'privat',
#   'sector',
#   'invest',
#   'fall',
#   'crore',
#   'follow',
#   'close',
#   'compon',
#   'collect',
#   'account',
#   'cent',
#   'total',
#   'shrinkag',
#   'govern',
#   'expenditur',
#   'fact',
#   'rise',
#   'cent',
#   'quarter',
#   'specif',
#   'relief',
#   'measur',
#   'institut',
#   'central',
#   'govern',
#   'compens',
#   'cent',
#   'total',
#   'fall',
#   'demand',
#   'instig',
#   'drop',
#   'consumpt',
#   'invest',
#   'relat',
#   'news',
#   'retail',
#   'msme',
#   'borrow',
#   'month',
#   'moratorium',
#   'loan',
#   'princip',
#   'repay',
#   'covid',
#   'impact',
#   'india',
#   'shrink',
#   'worst',
#   'rock',
#   'ralli',
#   'mirag',
#   'begin',
#   'multi',
#   'year',
#   'bull',
#   'street',
#   'expert',
#   'remain',
#   'divid',
#   'absenc',
#   'increas',
#   'govern',
#   'expenditur',
#   'appear',
#   'horizon',
#   'analyst',
#   'note',
#   'contract',
#   'card',
#   'upcom',
#   'quarter',
#   'india',
#   'record',
#   'contract',
#   'current',
#   'quarter',
#   'offici',
#   'enter',
#   'recess',
#   'defin',
#   'consecut',
#   'quarter',
#   'contract',
#   'india',
#   'begin',
#   'experi',
#   'sign',
#   'econom',
#   'recoveri',
#   'hing',
#   'entir',
#   'covid',
#   'outbreak',
#   'evolv',
#   'countri',
#   'come',
#   'week',
#   'month',
#   'india',
#   'add',
#   'million',
#   'case',
#   'infect',
#   'month',
#   'indic',
#   'nation',
#   'reach',
#   'peak',
#   'despit',
#   'centr',
#   'proceed',
#   'implement',
#   'relax',
#   'mobil',
#   'busi',
#   'activ',
#   'prompt',
#   'fear',
#   'resurg',
#   'infect',
#   'especi',
#   'metro',
#   'month',
#   'come',
#   'danger',
#   'close',
#   'see',
#   'healthcar',
#   'infrastructur',
#   'buckl',
#   'uncertainti',
#   'fear',
#   'continu',
#   'linger',
#   'demand',
#   'expect',
#   'remain',
#   'mute',
#   'lead',
#   'sustain',
#   'slump',
#   'busi',
#   'activ',
#   'result',
#   'exacerb',
#   'india',
#   'employ',
#   'crisi',
#   'india',
#   'unemploy',
#   'rat',
#   'accord',
#   'latest',
#   'data',
#   'cmie',
#   'return',
#   'near',
#   'covid',
#   'level',
#   'analyst',
#   'warn',
#   'bloodloss',
#   'sector',
#   'like',
#   'hospit',
#   'construct',
#   'manufactur',
#   'tourism',
#   'card',
#   'monday',
#   'govern',
#   'releas',
#   'econom',
#   'data',
#   'quarter',
#   'current',
#   'fiscal',
#   'year',
#   'reveal',
#   'histor',
#   'contract',
#   'cent',
#   'month',
#   'april',
#   'june',
#   'covid',
#   'outbreak',
#   'subsequ',
#   'lockdown',
#   'enforc',
#   'central',
#   'govern',
#   'state',
#   'govern',
#   'paralysi',
#   'busi',
#   'activ',
#   'trigger',
#   'largest',
#   'quarter',
#   'slump',
#   'india',
#   'figur',
#   'figur',
#   'publish',
#   'india',
#   'fourth',
#   'quarter',
#   'fiscal',
#   'stand',
#   'cent',
#   'overal',
#   'growth',
#   'fiscal',
#   'peg',
#   'cent',
#   'contract',
#   'india',
#   'larg',
#   'expect',
#   'economist',
#   'major',
#   'predict',
#   'shrinkag',
#   'greater',
#   'cent',
#   'latest',
#   'figur',
#   'spark',
#   'suggest',
#   'downward',
#   'revis',
#   'card',
#   'particular',
#   'give',
#   'lack',
#   'busi',
#   'activ',
#   'take',
#   'place',
#   'quarter',
#   'concern',
#   'data',
#   'collect',
#   'robust',
#   'typic',
#   'contract',
#   'cent',
#   'simpli',
#   'mean',
#   'total',
#   'valu',
#   'good',
#   'servic',
#   'fell',
#   'proport',
#   'compar',
#   'month',
#   'period',
#   'year',
#   'govern',
#   'data',
#   'show',
#   'except',
#   'agricultur',
#   'grow',
#   'rate',
#   'cent',
#   'sector',
#   'economi',
#   'contract',
#   'distress',
#   'acut',
#   'mine',
#   'cent',
#   'construct',
#   'cent',
#   'trade',
#   'hospit',
#   'servic',
#   'cent',
#   'manufactur',
#   'cent',
#   'sector',
#   'incident',
#   'sector',
#   'drive',
#   'employ',
#   'term',
#   'fuel',
#   'downward',
#   'trajectori',
#   'india',
#   'need',
#   'slight',
#   'deeper',
#   'look',
#   'economi',
#   'primari',
#   'engin',
#   'growth',
#   'consumpt',
#   'govern',
#   'expenditur',
#   'invest',
#   'nation',
#   'current',
#   'account',
#   'deficit',
#   'import',
#   'export',
#   'consumpt',
#   'typic',
#   'greatest',
#   'impact',
#   'quarter',
#   'account',
#   'cent',
#   'countri',
#   'invest',
#   'know',
#   'demand',
#   'privat',
#   'sector',
#   'enterpris',
#   'cent',
#   'india',
#   'govern',
#   'expenditur',
#   'share',
#   'stand',
#   'cent',
#   'india',
#   'current',
#   'account',
#   'deficit',
#   'histor',
#   'negat',
#   'record',
#   'posit',
#   'rat',
#   'quarter',
#   'past',
#   'impli',
#   'export',
#   'exceed',
#   'import',
#   'posit',
#   'ultim',
#   'clear',
#   'signal',
#   'mute',
#   'demand',
#   'import',
#   'drop',
#   'dire',
#   'level',
#   'drop',
#   'crore',
#   'privat',
#   'consumpt',
#   'cent',
#   'compar',
#   'period',
#   'year',
#   'driver',
#   'india',
#   'econom',
#   'contract',
#   'privat',
#   'sector',
#   'invest',
#   'fall',
#   'crore',
#   'follow',
#   'close',
#   'compon',
#   'collect',
#   'account',
#   'cent',
#   'total',
#   'shrinkag',
#   'govern',
#   'expenditur',
#   'fact',
#   'rise',
#   'cent',
#   'quarter',
#   'specif',
#   'relief',
#   'measur',
#   'institut',
#   'central',
#   'govern',
#   'compens',
#   'cent',
#   'total',
#   'fall',
#   'demand',
#   'instig',
#   'drop',
#   'consumpt',
#   'invest',
#   'relat',
#   'news',
#   'retail',
#   'msme',
#   'borrow',
#   'month',
#   'moratorium',
#   'loan',
#   'princip',
#   'repay',
#   'covid',
#   'impact',
#   'india',
#   'shrink',
#   'worst',
#   'rock',
#   'ralli',
#   'mirag',
#   'begin',
#   'multi',
#   'year',
#   'bull',
#   'street',
#   'expert',
#   'remain',
#   'divid',
#   'absenc',
#   'increas',
#   'govern',
#   'expenditur',
#   'appear',
#   'horizon',
#   'analyst',
#   'note',
#   'contract',
#   'card',
#   'upcom',
#   'quarter',
#   'india',
#   'record',
#   'contract',
#   'current',
#   'quarter',
#   'offici',
#   'enter',
#   'recess',
#   'defin',
#   'consecut',
#   'quarter',
#   'contract',
#   'india',
#   'begin',
#   'experi',
#   'sign',
#   'econom',
#   'recoveri',
#   'hing',
#   'entir',
#   'covid',
#   'outbreak',
#   'evolv',
#   'countri',
#   'come',
#   'week',
#   'month',
#   'india',
#   'add',
#   'million',
#   'case',
#   'infect',
#   'month',
#   'indic',
#   'nation',
#   'reach',
#   'peak',
#   'despit',
#   'centr',
#   'proceed',
#   'implement',
#   'relax',
#   'mobil',
#   'busi',
#   'activ',
#   'prompt',
#   'fear',
#   'resurg',
#   'infect',
#   'especi',
#   'metro',
#   'month',
#   'come',
#   'danger',
#   'close',
#   'see',
#   'healthcar',
#   'infrastructur',
#   'buckl',
#   'uncertainti',
#   'fear',
#   'continu',
#   'linger',
#   'demand',
#   'expect',
#   'remain',
#   'mute',
#   'lead',
#   'sustain',
#   'slump',
#   'busi',
#   'activ',
#   'result',
#   'exacerb',
#   'india',
#   'employ',
#   'crisi',
#   'india',
#   'unemploy',
#   'rat',
#   'accord',
#   'latest',
#   'data',
#   'cmie',
#   'return',
#   'near',
#   'covid',
#   'level',
#   'analyst',
#   'warn',
#   'bloodloss',
#   'sector',
#   'like',
#   'hospit',
#   'construct',
#   'manufactur',
#   'tourism',
#   'card',
#   'sensex',
#   'nifti',
#   'latest',
#   'market',
#   'news',
#   'etnownew',
#   'news',
#   'alert',
#   'financi',
#   'market',
#   'invest',
#   'strategi',
#   'suresh',
#   'raina',
#   'second',
#   'highest',
#   'scorer',
#   'histori',
#   'indian',
#   'premier',
#   'leagu',
#   'take',
#   'chennai',
#   'super',
#   'king',
#   'fan',
#   'surpris',
#   'decid',
#   'pull',
#   'tournament',
#   'raina',
#   'cite',
#   'person',
#   'reason',
#   'pull',
#   'edit',
#   'return',
#   'india',
#   'avail',
#   'season',
#   'report',
#   'rift',
#   'dhoni',
#   'raina',
#   'room',
#   'allot',
#   'leav',
#   'hander',
#   'speak',
#   'outlook',
#   'raina',
#   'speak',
#   'matter',
#   'reveal',
#   'pull',
#   'tournament',
#   'bubbl',
#   'safe',
#   'chanc',
#   'famili',
#   'littl',
#   'kid',
#   'elder',
#   'parent',
#   'return',
#   'famili',
#   'import',
#   'raina',
#   'say',
#   'decis',
#   'wasn',
#   'easi',
#   'raina',
#   'prepar',
#   'tournament',
#   'leav',
#   'chennai',
#   'tough',
#   'decis',
#   'like',
#   'famili',
#   'face',
#   'kid',
#   'surfac',
#   'dubai',
#   'covid',
#   'situat',
#   'look',
#   'good',
#   'decid',
#   'return',
#   'say',
#   'refut',
#   'report',
#   'rift',
#   'dhoni',
#   'raina',
#   'add',
#   'mahibhai',
#   'like',
#   'elder',
#   'brother',
#   'fabric',
#   'stori',
#   'raina',
#   'rule',
#   'possibl',
#   'make',
#   'comeback',
#   'tournament',
#   'depend',
#   'coronavirus',
#   'situat',
#   'dubai',
#   'player',
#   'forev',
#   'situat',
#   'get',
#   'better',
#   'dubai',
#   'return',
#   'door',
#   'close',
#   'raina',
#   'say',
#   'covid',
#   'scare',
#   'camp',
#   'member',
#   'conting',
#   'test',
#   'posit',
#   'covid',
#   'possibl',
#   'delay',
#   'schedul',
#   'deepak',
#   'chahar',
#   'ruturaj',
#   'gaekwad',
#   'cricket',
#   'test',
#   'posit',
#   'member',
#   'test',
#   'posit',
#   'support',
#   'staff',
#   'leav',
#   'dubai',
#   'organis',
#   'camp',
#   'chennai',
#   'come',
#   'scanner',
#   'recent',
#   'develop',
#   'camp',
#   'camp',
#   'even',
#   'august',
#   'raina',
#   'dhoni',
#   'hang',
#   'boot',
#   'intern',
#   'cricket',
#   'confus',
#   'tuesday',
#   'report',
#   'member',
#   'test',
#   'negat',
#   'test',
#   'conduct',
#   'monday',
#   'kasi',
#   'viswanathan',
#   'later',
#   'confirm',
#   'time',
#   'member',
#   'test',
#   'negat',
#   'test',
#   'posit',
#   'confus',
#   'ask',
#   'member',
#   'covid',
#   'test',
#   'account',
#   'exist',
#   'case',
#   'conting',
#   'member',
#   'test',
#   'negat',
#   'covid',
#   'origin',
#   'test',
#   'posit',
#   'say',
#   'latest',
#   'cricket',
#   'updat',
#   'live',
#   'score',
#   'sport',
#   'news',
#   'match',
#   'highlight',
#   'cricket',
#   'footbal',
#   'tenni',
#   'sport',
#   'timesnow']]

# %%
for idx, topic in lda_model.print_topics():
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.008*"say" + 0.007*"cours" + 0.007*"student" + 0.006*"job" + 0.005*"success" + 0.005*"work" + 0.005*"industri" + 0.005*"remot" + 0.004*"neet" + 0.004*"quarter"
#
#
# Topic: 1
# Words: 0.003*"practic" + 0.003*"posit" + 0.003*"profession" + 0.003*"print" + 0.003*"prevail" + 0.003*"presid" + 0.003*"presenc" + 0.003*"prepar" + 0.003*"programm" + 0.003*"post"
#
#
# Topic: 2
# Words: 0.011*"say" + 0.008*"cours" + 0.007*"student" + 0.006*"job" + 0.006*"quarter" + 0.005*"success" + 0.005*"remot" + 0.005*"industri" + 0.005*"neet" + 0.005*"work"
#
#
# Topic: 3
# Words: 0.011*"say" + 0.009*"cours" + 0.008*"student" + 0.007*"job" + 0.006*"quarter" + 0.006*"work" + 0.005*"growth" + 0.005*"success" + 0.005*"time" + 0.005*"remot"
#
#
# Topic: 4
# Words: 0.009*"say" + 0.007*"student" + 0.006*"cours" + 0.005*"quarter" + 0.005*"success" + 0.005*"neet" + 0.005*"remot" + 0.005*"rapid" + 0.004*"industri" + 0.004*"job"
#
#
# Topic: 5
# Words: 0.008*"cours" + 0.007*"say" + 0.007*"student" + 0.005*"job" + 0.005*"quarter" + 0.005*"neet" + 0.005*"success" + 0.005*"cent" + 0.005*"work" + 0.004*"rapid"
#
#
# Topic: 6
# Words: 0.014*"say" + 0.009*"job" + 0.009*"cours" + 0.008*"student" + 0.007*"work" + 0.006*"quarter" + 0.005*"economi" + 0.005*"remot" + 0.005*"covid" + 0.005*"india"
#
#
# Topic: 7
# Words: 0.009*"cours" + 0.009*"student" + 0.008*"say" + 0.006*"remot" + 0.006*"quarter" + 0.006*"job" + 0.005*"work" + 0.005*"success" + 0.005*"covid" + 0.005*"prepar"
#
#
# Topic: 8
# Words: 0.005*"cours" + 0.005*"say" + 0.005*"student" + 0.004*"job" + 0.004*"quarter" + 0.004*"success" + 0.004*"remot" + 0.004*"work" + 0.004*"industri" + 0.004*"programm"
#
#
# Topic: 9
# Words: 0.004*"say" + 0.004*"cours" + 0.003*"student" + 0.003*"job" + 0.003*"remot" + 0.003*"quarter" + 0.003*"work" + 0.003*"neet" + 0.003*"prepar" + 0.003*"success"
#
#
# Topic: 10
# Words: 0.006*"say" + 0.006*"cours" + 0.005*"student" + 0.005*"job" + 0.004*"quarter" + 0.004*"success" + 0.004*"work" + 0.004*"covid" + 0.004*"rapid" + 0.004*"month"
#
#
# Topic: 11
# Words: 0.010*"say" + 0.009*"cours" + 0.008*"student" + 0.006*"job" + 0.005*"quarter" + 0.005*"neet" + 0.005*"work" + 0.005*"remot" + 0.005*"india" + 0.005*"economi"
#
#
# Topic: 12
# Words: 0.004*"say" + 0.004*"student" + 0.004*"cours" + 0.004*"job" + 0.003*"remot" + 0.003*"prepar" + 0.003*"neet" + 0.003*"work" + 0.003*"cent" + 0.003*"growth"
#
#
# Topic: 13
# Words: 0.007*"say" + 0.007*"cours" + 0.006*"student" + 0.006*"job" + 0.005*"remot" + 0.004*"work" + 0.004*"neet" + 0.004*"quarter" + 0.004*"growth" + 0.004*"success"
#
#
# Topic: 14
# Words: 0.032*"say" + 0.025*"cours" + 0.024*"student" + 0.017*"job" + 0.014*"quarter" + 0.012*"success" + 0.012*"work" + 0.010*"neet" + 0.010*"remot" + 0.009*"economi"
#
#
# Topic: 15
# Words: 0.007*"cours" + 0.007*"say" + 0.006*"student" + 0.006*"quarter" + 0.005*"job" + 0.005*"success" + 0.005*"neet" + 0.005*"work" + 0.004*"cent" + 0.004*"time"
#
#
# Topic: 16
# Words: 0.009*"say" + 0.008*"student" + 0.007*"cours" + 0.007*"job" + 0.005*"success" + 0.005*"remot" + 0.005*"quarter" + 0.005*"work" + 0.005*"prepar" + 0.005*"time"
#
#
# Topic: 17
# Words: 0.008*"say" + 0.006*"student" + 0.006*"cours" + 0.005*"success" + 0.005*"job" + 0.004*"quarter" + 0.004*"neet" + 0.004*"work" + 0.004*"remot" + 0.004*"growth"
#
#
# Topic: 18
# Words: 0.006*"say" + 0.006*"cours" + 0.006*"student" + 0.005*"quarter" + 0.005*"job" + 0.004*"success" + 0.004*"work" + 0.004*"neet" + 0.004*"rapid" + 0.004*"cent"
#
#
# Topic: 19
# Words: 0.005*"say" + 0.005*"student" + 0.005*"job" + 0.005*"cours" + 0.004*"work" + 0.004*"rapid" + 0.004*"success" + 0.004*"quarter" + 0.004*"expect" + 0.004*"remot"
